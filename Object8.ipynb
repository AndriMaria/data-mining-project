# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes=True)

Object8 = pd.read_csv('S014.csv')

print(Object8.columns)
print(Object8.info())
print(Object8.describe())
print(Object8.isnull().sum())
Object8["label"].unique()
Object8["label"].value_counts().plot(kind='bar',title='Συμμετεχων 8(S014)')
# Out:
# Index(['timestamp', 'back_x', 'back_y', 'back_z', 'thigh_x', 'thigh_y',
#        'thigh_z', 'label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366487 entries, 0 to 366486
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  366487 non-null  object
#  1   back_x     366487 non-null  float64
#  2   back_y     366487 non-null  float64
#  3   back_z     366487 non-null  float64
#  4   thigh_x    366487 non-null  float64
#  5   thigh_y    366487 non-null  float64
#  6   thigh_z    366487 non-null  float64
#  7   label      366487 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 22.4+ MB
# None
#               back_x         back_y         back_z        thigh_x  \
# count  366487.000000  366487.000000  366487.000000  366487.000000
# mean       -0.922165      -0.028864      -0.064206      -0.380881
# ...

# %%
Object8['back_x'].hist()
plt.show()
fig = plt.figure()
Object8['back_y'].hist()
plt.show()
fig1 = plt.figure()
Object8['back_z'].hist()
plt.show()
fig3 = plt.figure()
Object8['thigh_x'].hist()
plt.show()
fig4 = plt.figure()
Object8['thigh_y'].hist()
plt.show()
fig5 = plt.figure()
Object8['thigh_z'].hist()
plt.show()
fig6 = plt.figure()


ax = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax.plot3D(Object8['back_x'],Object8['back_y'], Object8['back_z'])
ax.set_title('Back_14')
plt.show()




ax1 = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax1.plot3D(Object8['thigh_x'],Object8['thigh_y'],Object8['thigh_z'])
ax1.set_title('Thigh_14')
plt.show()
