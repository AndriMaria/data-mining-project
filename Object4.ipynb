# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes=True)

Object4 = pd.read_csv('S010.csv')

print(Object4.columns)
print(Object4.info())
print(Object4.describe())
print(Object4.isnull().sum())
Object4["label"].value_counts().plot(kind='bar',title='Συμμετεχων 4(S010)')
# Out:
# Index(['timestamp', 'back_x', 'back_y', 'back_z', 'thigh_x', 'thigh_y',
#        'thigh_z', 'label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351649 entries, 0 to 351648
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  351649 non-null  object
#  1   back_x     351649 non-null  float64
#  2   back_y     351649 non-null  float64
#  3   back_z     351649 non-null  float64
#  4   thigh_x    351649 non-null  float64
#  5   thigh_y    351649 non-null  float64
#  6   thigh_z    351649 non-null  float64
#  7   label      351649 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 21.5+ MB
# None
#               back_x         back_y         back_z        thigh_x  \
# count  351649.000000  351649.000000  351649.000000  351649.000000
# mean       -1.019898      -0.002224      -0.014543      -0.905389
# ...

# %%
Object4['back_x'].hist()
plt.show()
fig = plt.figure()
Object4['back_y'].hist()
plt.show()
fig1 = plt.figure()
Object4['back_z'].hist()
plt.show()
fig3 = plt.figure()
Object4['thigh_x'].hist()
plt.show()
fig4 = plt.figure()
Object4['thigh_y'].hist()
plt.show()
fig5 = plt.figure()
Object4['thigh_z'].hist()
plt.show()
fig6 = plt.figure()


ax = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax.plot3D(Object4['back_x'], Object4['back_y'], Object4['back_z'])
ax.set_title('Back_10')
plt.show()


ax1 = plt.axes(projection='3d')

z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax1.plot3D(Object4['thigh_x'], Object4['thigh_y'],Object4['thigh_z'])
ax1.set_title('Thigh_10')
plt.show()

# %%
Object4["label"].unique()
# Out:
# array([6, 3, 1, 5, 4, 7])
