# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes=True)

Object9 = pd.read_csv('S015.csv')

print(Object9.columns)
print(Object9.info())
print(Object9.describe())
print(Object9.isnull().sum())
Object9["label"].unique()

Object9["label"].value_counts().plot(kind='bar',title='Συμμετέχων 9(S015)')
# Out:
# Index(['timestamp', 'index', 'back_x', 'back_y', 'back_z', 'thigh_x',
#        'thigh_y', 'thigh_z', 'label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418392 entries, 0 to 418391
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  418392 non-null  object
#  1   index      418392 non-null  int64
#  2   back_x     418392 non-null  float64
#  3   back_y     418392 non-null  float64
#  4   back_z     418392 non-null  float64
#  5   thigh_x    418392 non-null  float64
#  6   thigh_y    418392 non-null  float64
#  7   thigh_z    418392 non-null  float64
#  8   label      418392 non-null  int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.7+ MB
# None
#                index         back_x         back_y         back_z  \
# count  418392.000000  418392.000000  418392.000000  418392.000000
# mean   211948.090097      -0.800805       0.047076      -0.136345
# ...

# %%
Object9['back_x'].hist()
plt.show()
fig = plt.figure()
Object9['back_y'].hist()
plt.show()
fig1 = plt.figure()
Object9['back_z'].hist()
plt.show()
fig3 = plt.figure()
Object9['thigh_x'].hist()
plt.show()
fig4 = plt.figure()
Object9['thigh_y'].hist()
plt.show()
fig5 = plt.figure()
Object9['thigh_z'].hist()
plt.show()
fig6 = plt.figure()


ax = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

ax.plot3D(Object9['back_x'],Object9['back_y'], Object9['back_z'])
ax.set_title('Back_15')
plt.show()

ax1 = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax1.plot3D(Object9['thigh_x'],Object9['thigh_y'],Object9['thigh_z'])
ax1.set_title('Thigh_15')
plt.show()
