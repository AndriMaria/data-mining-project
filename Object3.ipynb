# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes=True)

Object3 = pd.read_csv('S009.csv')

print(Object3.columns)
print(Object3.info())
print(Object3.describe())
print(Object3.isnull().sum())
Object3["label"].value_counts().plot(kind='bar',title='Συμμετεχων 3(S009)')
# Out:
# Index(['timestamp', 'back_x', 'back_y', 'back_z', 'thigh_x', 'thigh_y',
#        'thigh_z', 'label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154464 entries, 0 to 154463
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  154464 non-null  object
#  1   back_x     154464 non-null  float64
#  2   back_y     154464 non-null  float64
#  3   back_z     154464 non-null  float64
#  4   thigh_x    154464 non-null  float64
#  5   thigh_y    154464 non-null  float64
#  6   thigh_z    154464 non-null  float64
#  7   label      154464 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 9.4+ MB
# None
#               back_x         back_y         back_z        thigh_x  \
# count  154464.000000  154464.000000  154464.000000  154464.000000
# mean       -0.944405      -0.056068       0.312780      -0.957280
# ...

# %%
Object3['back_x'].hist()
plt.show()
fig = plt.figure()
Object3['back_y'].hist()
plt.show()
fig1 = plt.figure()
Object3['back_z'].hist()
plt.show()
fig3 = plt.figure()
Object3['thigh_x'].hist()
plt.show()
fig4 = plt.figure()
Object3['thigh_y'].hist()
plt.show()
fig5 = plt.figure()
Object3['thigh_z'].hist()
plt.show()
fig6 = plt.figure()


ax = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax.plot3D(Object3['back_x'], Object3['back_y'], Object3['back_z'])
ax.set_title('Back_9')
plt.show()


ax1 = plt.axes(projection='3d')

z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax1.plot3D(Object3['thigh_x'], Object3['thigh_y'],Object3['thigh_z'])
ax1.set_title('Thigh_9')
plt.show()

# %%
Object3["label"].unique()
# Out:
# array([  6,   1,   4,   3,  13,  14, 130, 140,   5])
