# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes=True)

Object1 = pd.read_csv('S006.csv')

# %%
Object1.head()
print(Object1.columns)
print(Object1.info())
print(Object1.describe())
# Out:
# Index(['timestamp', 'back_x', 'back_y', 'back_z', 'thigh_x', 'thigh_y',
#        'thigh_z', 'label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408709 entries, 0 to 408708
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  408709 non-null  object
#  1   back_x     408709 non-null  float64
#  2   back_y     408709 non-null  float64
#  3   back_z     408709 non-null  float64
#  4   thigh_x    408709 non-null  float64
#  5   thigh_y    408709 non-null  float64
#  6   thigh_z    408709 non-null  float64
#  7   label      408709 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 24.9+ MB
# None
#               back_x         back_y         back_z        thigh_x  \
# count  408709.000000  408709.000000  408709.000000  408709.000000
# mean       -0.802201      -0.000687      -0.274718      -0.370317
# ...

# %%
filtered_df = Object1[Object1['back_x'] > -0.71743775]
mean_value = Object1['back_x'].mean()
summary_stats = Object1.describe()
print(summary_stats)
# Out:
#               back_x         back_y         back_z        thigh_x  \
# count  408709.000000  408709.000000  408709.000000  408709.000000
# mean       -0.802201      -0.000687      -0.274718      -0.370317
# std         0.238347       0.189062       0.441805       0.506666
# min        -3.542889      -3.016498      -1.024363      -6.844045
# 25%        -0.983647       0.001063      -0.702338      -0.952840
# 50%        -0.937195       0.033240      -0.277446      -0.277711
# 75%        -0.654541       0.074822       0.064811       0.068999
# max         0.952109       2.569339       1.628023       3.898547
#
#              thigh_y        thigh_z          label
# count  408709.000000  408709.000000  408709.000000
# mean        0.143471       0.617527      10.190187
# std         0.213864       0.536430      20.328336
# min        -5.757406      -4.884791       1.000000
# 25%         0.022534       0.144114       6.000000
# 50%         0.086248       0.924066       7.000000
# ...

# %%
Object1["label"].value_counts().plot(kind='bar',title='Συμμετεχων 1(S006)')
# Out:
# <Axes: title={'center': 'Συμμετεχων 1(S006)'}, xlabel='label'>

# %%
print(Object1.isnull().sum())
# Out:
# timestamp    0
# back_x       0
# back_y       0
# back_z       0
# thigh_x      0
# thigh_y      0
# thigh_z      0
# label        0
# dtype: int64

# %%
Object1['back_x'].hist()
plt.show()
fig = plt.figure()
Object1['back_y'].hist()
plt.show()
fig1 = plt.figure()
Object1['back_z'].hist()
plt.show()
fig3 = plt.figure()
Object1['thigh_x'].hist()
plt.show()
fig4 = plt.figure()
Object1['thigh_y'].hist()
plt.show()
fig5 = plt.figure()
Object1['thigh_z'].hist()
plt.show()
fig6 = plt.figure()

ax = plt.axes(projection='3d')

# defining all 3 axis
z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax.plot3D(Object1['back_x'], Object1['back_y'], Object1['back_z'])
ax.set_title('Back_6')
plt.show()




ax1 = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax1.plot3D(Object1['thigh_x'], Object1['thigh_y'], Object1['thigh_z'])
ax1.set_title('Thigh_6')
plt.show()

# %%
Object1 = {'label': [6, 13, 3, 1, 7, 4, 5, 8, 13, 14, 6, 13, 1, 4, 5]}  
df = pd.DataFrame(Object1)
value_counts = df['label'].value_counts()

plt.figure(figsize=(12, 6))  # Προσαρμογή μεγέθους γραφήματος
value_counts.plot(kind='bar')
plt.xlabel('Τιμές label')
plt.ylabel('Συχνότητα')
plt.title('Συμμετέχων 1(S008)')
plt.xticks(rotation=45)
plt.tight_layout()


plt.show()
