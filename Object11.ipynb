# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes=True)

Object11 = pd.read_csv('S017.csv')

print(Object11.columns)
print(Object11.info())
print(Object11.describe())
print(Object11.isnull().sum())
Object11["label"].unique()
Object11["label"].value_counts().plot(kind='bar')
Object11["label"].value_counts().plot(kind='bar',title='Συμμετεχων 11(S017)')
# Out:
# Index(['timestamp', 'back_x', 'back_y', 'back_z', 'thigh_x', 'thigh_y',
#        'thigh_z', 'label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366609 entries, 0 to 366608
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  366609 non-null  object
#  1   back_x     366609 non-null  float64
#  2   back_y     366609 non-null  float64
#  3   back_z     366609 non-null  float64
#  4   thigh_x    366609 non-null  float64
#  5   thigh_y    366609 non-null  float64
#  6   thigh_z    366609 non-null  float64
#  7   label      366609 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 22.4+ MB
# None
#               back_x         back_y         back_z        thigh_x  \
# count  366609.000000  366609.000000  366609.000000  366609.000000
# mean       -0.877122       0.044456      -0.023970      -0.442412
# ...

# %%
Object11['back_x'].hist()
plt.show()
fig = plt.figure()
Object11['back_y'].hist()
plt.show()
fig1 = plt.figure()
Object11['back_z'].hist()
plt.show()
fig3 = plt.figure()
Object11['thigh_x'].hist()
plt.show()
fig4 = plt.figure()
Object11['thigh_y'].hist()
plt.show()
fig5 = plt.figure()
Object11['thigh_z'].hist()
plt.show()
fig6 = plt.figure()

ax = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

ax.plot3D(Object11['back_x'],Object11['back_y'], Object11['back_z'])
ax.set_title('Back_17')
plt.show()

ax1 = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax1.plot3D(Object11['thigh_x'],Object11['thigh_y'],Object11['thigh_z'])
ax1.set_title('Thigh_17')
plt.show()
