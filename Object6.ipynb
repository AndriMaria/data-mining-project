# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes=True)

Object6 = pd.read_csv('S013.csv')

print(Object6.columns)
print(Object6.info())
print(Object6.describe())
print(Object6.isnull().sum())
Object6["label"].unique()

Object6["label"].value_counts().plot(kind='bar',title='Συμμετεχων 6(S013)')
# Out:
# Index(['timestamp', 'back_x', 'back_y', 'back_z', 'thigh_x', 'thigh_y',
#        'thigh_z', 'label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369077 entries, 0 to 369076
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  369077 non-null  object
#  1   back_x     369077 non-null  float64
#  2   back_y     369077 non-null  float64
#  3   back_z     369077 non-null  float64
#  4   thigh_x    369077 non-null  float64
#  5   thigh_y    369077 non-null  float64
#  6   thigh_z    369077 non-null  float64
#  7   label      369077 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 22.5+ MB
# None
#               back_x         back_y         back_z        thigh_x  \
# count  369077.000000  369077.000000  369077.000000  369077.000000
# mean       -0.947547      -0.028837      -0.238492      -0.504721
# ...

# %%
Object6['back_x'].hist()
plt.show()
fig = plt.figure()
Object6['back_y'].hist()
plt.show()
fig1 = plt.figure()
Object6['back_z'].hist()
plt.show()
fig3 = plt.figure()
Object6['thigh_x'].hist()
plt.show()
fig4 = plt.figure()
Object6['thigh_y'].hist()
plt.show()
fig5 = plt.figure()
Object6['thigh_z'].hist()
plt.show()
fig6 = plt.figure()

ax = plt.axes(projection='3d')

z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

ax.plot3D(Object6['back_x'], Object6['back_y'], Object6['back_z'])
ax.set_title('Back_13')
plt.show()




ax1 = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

ax1.plot3D(Object6['thigh_x'],Object6['thigh_y'],Object6['thigh_z'])
ax1.set_title('Thigh_13')
plt.show()
