# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes=True)

Object5 = pd.read_csv('S012.csv')

print(Object5.columns)
print(Object5.info())
print(Object5.describe())
print(Object5.isnull().sum())
Object5["label"].value_counts().plot(kind='bar',title='Συμμετεχων 5(S012)')
# Out:
# Index(['timestamp', 'back_x', 'back_y', 'back_z', 'thigh_x', 'thigh_y',
#        'thigh_z', 'label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382414 entries, 0 to 382413
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  382414 non-null  object
#  1   back_x     382414 non-null  float64
#  2   back_y     382414 non-null  float64
#  3   back_z     382414 non-null  float64
#  4   thigh_x    382414 non-null  float64
#  5   thigh_y    382414 non-null  float64
#  6   thigh_z    382414 non-null  float64
#  7   label      382414 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 23.3+ MB
# None
#               back_x         back_y         back_z        thigh_x  \
# count  382414.000000  382414.000000  382414.000000  382414.000000
# mean       -0.915515       0.005064      -0.130062      -0.321236
# ...

# %%
Object5['back_x'].hist()
plt.show()
fig = plt.figure()
Object5['back_y'].hist()
plt.show()
fig1 = plt.figure()
Object5['back_z'].hist()
plt.show()
fig3 = plt.figure()
Object5['thigh_x'].hist()
plt.show()
fig4 = plt.figure()
Object5['thigh_y'].hist()
plt.show()
fig5 = plt.figure()
Object5['thigh_z'].hist()
plt.show()
fig6 = plt.figure()


ax = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax.plot3D(Object5['back_x'], Object5['back_y'], Object5['back_z'])
ax.set_title('Back_12')
plt.show()


ax1 = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax1.plot3D(Object5['thigh_x'], Object5['thigh_y'],Object5['thigh_z'])
ax1.set_title('Thigh_12')
plt.show()

# %%
Object5.dtypes
# Out:
# timestamp     object
# back_x       float64
# back_y       float64
# back_z       float64
# thigh_x      float64
# thigh_y      float64
# thigh_z      float64
# label          int64
# dtype: object

# %%
Object5.shape
# Out:
# (382414, 8)

# %%
Object5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382414 entries, 0 to 382413
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  382414 non-null  object
#  1   back_x     382414 non-null  float64
#  2   back_y     382414 non-null  float64
#  3   back_z     382414 non-null  float64
#  4   thigh_x    382414 non-null  float64
#  5   thigh_y    382414 non-null  float64
#  6   thigh_z    382414 non-null  float64
#  7   label      382414 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 23.3+ MB

# %%
Object5["label"].unique()
# Out:
# array([6, 3, 7, 1, 5, 4, 2, 8])
