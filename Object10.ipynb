# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
sns.set(color_codes=True)

Object10 = pd.read_csv('S016.csv')

print(Object10.columns)
print(Object10.info())
print(Object10.describe())
print(Object10.isnull().sum())
Object10["label"].unique()

Object10["label"].value_counts().plot(kind='bar',title='Συμμετεχων 10(S016)')
# Out:
# Index(['timestamp', 'back_x', 'back_y', 'back_z', 'thigh_x', 'thigh_y',
#        'thigh_z', 'label'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355418 entries, 0 to 355417
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  355418 non-null  object
#  1   back_x     355418 non-null  float64
#  2   back_y     355418 non-null  float64
#  3   back_z     355418 non-null  float64
#  4   thigh_x    355418 non-null  float64
#  5   thigh_y    355418 non-null  float64
#  6   thigh_z    355418 non-null  float64
#  7   label      355418 non-null  int64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 21.7+ MB
# None
#               back_x         back_y         back_z        thigh_x  \
# count  355418.000000  355418.000000  355418.000000  355418.000000
# mean       -0.809658      -0.085955      -0.222711      -0.490494
# ...

# %%
Object10["label"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='label'>

# %%
Object10['back_x'].hist()
plt.show()
fig = plt.figure()
Object10['back_y'].hist()
plt.show()
fig1 = plt.figure()
Object10['back_z'].hist()
plt.show()
fig3 = plt.figure()
Object10['thigh_x'].hist()
plt.show()
fig4 = plt.figure()
Object10['thigh_y'].hist()
plt.show()
fig5 = plt.figure()
Object10['thigh_z'].hist()
plt.show()
fig6 = plt.figure()


ax = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax.plot3D(Object10['back_x'],Object10['back_y'], Object10['back_z'])
ax.set_title('Back_16')
plt.show()




ax1 = plt.axes(projection='3d')


z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)


ax1.plot3D(Object10['thigh_x'],Object10['thigh_y'],Object10['thigh_z'])
ax1.set_title('Thigh_16')
plt.show()
